# %%
from petaspin.simulations import simulation
from pathlib import Path
import matplotlib.pyplot as plt

# %%
sim_path = r"C:\Users\benja\Documents\Git projects\RKKY-bilayer---PETASPIN\sim0"
sim = simulation(sim_path)

# %%
conv = sim.convergence(plot = True, threshold = 1e-2)
print(' converged = ', conv)
# Out:
#  converged =  True

# %%
magnetization = sim.magnetization()
magnetization.keys()
# Out:
# dict_keys(['time', 'M', 'dM_dt', 'mx_mean', 'my_mean', 'mz_mean'])

# %%
time = magnetization['time']
mx = magnetization['mx_mean']

plt.plot(time, mx)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
